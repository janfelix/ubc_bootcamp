# %%
def zero():
    return 0

# %%
zero()
# Out:
# 0

# %%
print 'return value:', zero()
# Out:
# return value: 0

# %%
import novice
def make_thumbnail(filename, width):
    picture = novice.open(filename) # to comment shit
    new_height = int(picture.height * float(width)/picture.width)
    picture.size = (width, new_height)
    return picture

# %%
tn = make_thumbnail('flower.png', 100)
tn
# Out:
# Picture (format: png, path: None, modified: True)

# %%
bike = make_thumbnail('biking.png', 100)

# %%
bike
# Out:
# Picture (format: png, path: None, modified: True)

# %%
bike
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8c9a21825a5> in <module>()
# ----> 1 bike
#
# NameError: name 'bike' is not defined
